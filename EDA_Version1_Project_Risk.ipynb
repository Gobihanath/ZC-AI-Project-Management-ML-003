# %% [markdown]
# <a href="https://colab.research.google.com/github/Gobihanath/ZC-AI-Project-Management-ML-003/blob/main/EDA_Version1_Project_Risk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install --upgrade pandas numpy matplotlib seaborn statsmodels
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 89.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 109.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.3 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.3 which is incompatible.
# cupy-cuda12x 13.3.0 requires numpy<2.3,>=1.22, but you have numpy 2.3.3 which is incompatible.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files, drive
from IPython.display import display

# %%
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set(style="whitegrid")

# %%
#csv upload
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8238f307-ef48-409f-b89f-79357c706122" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8238f307-ef48-409f-b89f-79357c706122">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('project_risk_raw_dataset.csv')

# %%
print("Data shape:", df.shape)
# Out:
# Data shape: (4000, 51)

# %%
df.head()
# Out:
#   Project_ID   Project_Type  Team_Size  Project_Budget_USD  \
# 0  PROJ_0001   Construction         32          1526276.55
# 1  PROJ_0002  Manufacturing          2           390790.15
# 2  PROJ_0003  Manufacturing          2           246674.76
# 3  PROJ_0004             IT         12          1427830.63
# 4  PROJ_0005   Construction         24          1696746.64
#
#    Estimated_Timeline_Months  Complexity_Score  Stakeholder_Count  \
# 0                         32              9.70                 16
# 1                          9              2.72                  9
# 2                          6              2.04                  7
# 3                         17              7.54                 16
# 4                         24              6.68                 17
#
#   Methodology_Used Team_Experience_Level  Past_Similar_Projects  \
# 0        Waterfall                Senior                      3
# 1           Kanban                 Mixed                      0
# ...

# %%
df.columns.tolist()
# Out:
# ['Project_ID',
#  'Project_Type',
#  'Team_Size',
#  'Project_Budget_USD',
#  'Estimated_Timeline_Months',
#  'Complexity_Score',
#  'Stakeholder_Count',
#  'Methodology_Used',
#  'Team_Experience_Level',
#  'Past_Similar_Projects',
#  'External_Dependencies_Count',
#  'Change_Request_Frequency',
#  'Project_Phase',
#  'Requirement_Stability',
#  'Team_Turnover_Rate',
#  'Vendor_Reliability_Score',
#  'Historical_Risk_Incidents',
#  'Communication_Frequency',
#  'Regulatory_Compliance_Level',
#  'Technology_Familiarity',
#  'Geographical_Distribution',
#  'Stakeholder_Engagement_Level',
#  'Schedule_Pressure',
#  'Budget_Utilization_Rate',
#  'Executive_Sponsorship',
#  'Funding_Source',
#  'Market_Volatility',
#  'Integration_Complexity',
#  'Resource_Availability',
#  'Priority_Level',
#  'Organizational_Change_Frequency',
#  'Cross_Functional_Dependencies',
#  'Previous_Delivery_Success_Rate',
#  'Technical_Debt_Level',
#  'Project_Manager_Experience',
#  'Org_Process_Maturity',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 51 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Project_ID                       4000 non-null   object
#  1   Project_Type                     4000 non-null   object
#  2   Team_Size                        4000 non-null   int64
#  3   Project_Budget_USD               4000 non-null   float64
#  4   Estimated_Timeline_Months        4000 non-null   int64
#  5   Complexity_Score                 4000 non-null   float64
#  6   Stakeholder_Count                4000 non-null   int64
#  7   Methodology_Used                 4000 non-null   object
#  8   Team_Experience_Level            4000 non-null   object
#  9   Past_Similar_Projects            4000 non-null   int64
#  10  External_Dependencies_Count      4000 non-null   int64
#  11  Change_Request_Frequency         4000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Team_Size  Project_Budget_USD  Estimated_Timeline_Months  \
# count    4000.00             4000.00                    4000.00
# mean       15.39          1143031.50                      17.15
# std         9.22           590878.12                       6.93
# min         2.00           159355.55                       2.00
# 25%         9.00           692532.92                      12.00
# 50%        13.00          1007471.80                      17.00
# 75%        20.00          1475870.20                      22.00
# max        50.00          3768354.37                      36.00
#
#        Complexity_Score  Stakeholder_Count  Past_Similar_Projects  \
# count           4000.00            4000.00                4000.00
# mean               6.19              11.13                   1.97
# std                2.21               4.43                   1.75
# min                1.62               2.00                   0.00
# ...

# %%
missing = df.isnull().sum().sort_values(ascending=False)
display(missing[missing > 0])
# Out:
# Tech_Environment_Stability    2619
# Risk_Management_Maturity       791
# Change_Control_Maturity        780
# dtype: int64

# %%
print("\nCategorical summary (top values):")
display(df.select_dtypes(include=['object','category']).describe())
# Out:
# Categorical summary (top values):
#        Project_ID Project_Type Methodology_Used Team_Experience_Level  \
# count        4000         4000             4000                  4000
# unique       4000            6                5                     4
# top     PROJ_3984           IT            Agile                 Mixed
# freq            1         1381             1124                  1593
#
#        Project_Phase Requirement_Stability Regulatory_Compliance_Level  \
# count           4000                  4000                        4000
# unique             5                     3                           4
# top       Initiation              Moderate                      Medium
# freq             834                  2063                        1032
#
#        Technology_Familiarity Stakeholder_Engagement_Level  \
# count                    4000                         4000
# unique                      3                            5
# ...

# %%
irrelevant = [
    'Complexity_Score','Change_Request_Frequency','Team_Turnover_Rate',
    'Communication_Frequency','Geographical_Distribution','Market_Volatility',
    'Cross_Functional_Dependencies','Technical_Debt_Level','Seasonal_Risk_Factor'
]

# %%
df.head()
# Out:
#   Project_ID   Project_Type  Team_Size  Project_Budget_USD  \
# 0  PROJ_0001   Construction         32          1526276.55
# 1  PROJ_0002  Manufacturing          2           390790.15
# 2  PROJ_0003  Manufacturing          2           246674.76
# 3  PROJ_0004             IT         12          1427830.63
# 4  PROJ_0005   Construction         24          1696746.64
#
#    Estimated_Timeline_Months  Complexity_Score  Stakeholder_Count  \
# 0                         32              9.70                 16
# 1                          9              2.72                  9
# 2                          6              2.04                  7
# 3                         17              7.54                 16
# 4                         24              6.68                 17
#
#   Methodology_Used Team_Experience_Level  Past_Similar_Projects  \
# 0        Waterfall                Senior                      3
# 1           Kanban                 Mixed                      0
# ...

# %%
present = [c for c in irrelevant if c in df.columns]
print("Columns found and will be dropped:", present)
# Out:
# Columns found and will be dropped: ['Complexity_Score', 'Change_Request_Frequency', 'Team_Turnover_Rate', 'Communication_Frequency', 'Geographical_Distribution', 'Market_Volatility', 'Cross_Functional_Dependencies', 'Technical_Debt_Level', 'Seasonal_Risk_Factor']

# %%
df = df.drop(columns=present, errors='ignore')
print("New shape:", df.shape)
# Out:
# New shape: (4000, 42)

# %%
for col in df.columns:
    if 'date' in col.lower():
        try:
            df[col] = pd.to_datetime(df[col])
            print("Converted to datetime:", col)
        except Exception:
            pass

# %%
for col in df.columns:
    if df[col].dtype == 'object':

        try:
            df[col] = pd.to_numeric(df[col].str.replace(',',''), errors='ignore')
        except Exception:
            pass
display(df.dtypes)
# Out:
# /tmp/ipython-input-1222355154.py:5: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col].str.replace(',',''), errors='ignore')
# Project_ID                          object
# Project_Type                        object
# Team_Size                            int64
# Project_Budget_USD                 float64
# Estimated_Timeline_Months            int64
# Stakeholder_Count                    int64
# Methodology_Used                    object
# Team_Experience_Level               object
# Past_Similar_Projects                int64
# External_Dependencies_Count          int64
# Project_Phase                       object
# Requirement_Stability               object
# Vendor_Reliability_Score           float64
# Historical_Risk_Incidents            int64
# Regulatory_Compliance_Level         object
# Technology_Familiarity              object
# ...

# %%
# Compute % missing and decide strategy
missing_pct = df.isnull().mean().sort_values(ascending=False) * 100
display(missing_pct[missing_pct > 0].round(2))

cols_to_drop = missing_pct[missing_pct > 50].index.tolist()
print("Columns with >50% missing (consider dropping):", cols_to_drop)
# Out:
# Series([], dtype: float64)
# Columns with >50% missing (consider dropping): []

# %%
# Fill numeric missing with median
num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
for c in num_cols:
    if df[c].isnull().any():
        df[c].fillna(df[c].median(), inplace=True)

# %%
# Fill categorical with mode
cat_cols = df.select_dtypes(include=['object','category']).columns.tolist()
for c in cat_cols:
    if df[c].isnull().any():
        df[c].fillna(df[c].mode().iloc[0], inplace=True)

print("Missing values after simple imputation:")
display(df.isnull().sum().sort_values(ascending=False).head(20))
# Out:
# Missing values after simple imputation:
# Project_ID                      0
# Project_Type                    0
# Team_Size                       0
# Project_Budget_USD              0
# Estimated_Timeline_Months       0
# Stakeholder_Count               0
# Methodology_Used                0
# Team_Experience_Level           0
# Past_Similar_Projects           0
# External_Dependencies_Count     0
# Project_Phase                   0
# Requirement_Stability           0
# Vendor_Reliability_Score        0
# Historical_Risk_Incidents       0
# Regulatory_Compliance_Level     0
# Technology_Familiarity          0
# Stakeholder_Engagement_Level    0
# Schedule_Pressure               0
# Budget_Utilization_Rate         0
# Executive_Sponsorship           0
# dtype: int64

# %%
# 7. Prepare numeric and categorical lists
numeric_df = df.select_dtypes(include=[np.number]).copy()
categorical_cols = df.select_dtypes(include=['object','category']).columns.tolist()
print("Numeric columns:", numeric_df.columns.tolist())
print("Categorical columns:", categorical_cols)
# Out:
# Numeric columns: ['Team_Size', 'Project_Budget_USD', 'Estimated_Timeline_Months', 'Stakeholder_Count', 'Past_Similar_Projects', 'External_Dependencies_Count', 'Vendor_Reliability_Score', 'Historical_Risk_Incidents', 'Schedule_Pressure', 'Budget_Utilization_Rate', 'Integration_Complexity', 'Resource_Availability', 'Organizational_Change_Frequency', 'Previous_Delivery_Success_Rate', 'Project_Start_Month', 'Current_Phase_Duration_Months']
# ...

# %%
# Correlation matrix
corr = numeric_df.corr(method='pearson')
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Extract top correlated pairs (absolute value, exclude self-pairs)
corr_pairs = corr.abs().unstack().reset_index()
corr_pairs.columns = ['feature_1','feature_2','abs_corr']

# %%
# remove self correlations
corr_pairs = corr_pairs[corr_pairs['feature_1'] != corr_pairs['feature_2']]

corr_pairs['pair'] = corr_pairs.apply(lambda r: tuple(sorted([r.feature_1, r.feature_2])), axis=1)
corr_pairs = corr_pairs.drop_duplicates(subset=['pair']).sort_values('abs_corr', ascending=False)
display(corr_pairs[['feature_1','feature_2','abs_corr']].head(15))
# Out:
#                     feature_1                      feature_2  abs_corr
# 19         Project_Budget_USD              Stakeholder_Count      0.89
# 1                   Team_Size             Project_Budget_USD      0.89
# 18         Project_Budget_USD      Estimated_Timeline_Months      0.86
# 2                   Team_Size      Estimated_Timeline_Months      0.86
# 3                   Team_Size              Stakeholder_Count      0.79
# 35  Estimated_Timeline_Months              Stakeholder_Count      0.77
# 47  Estimated_Timeline_Months  Current_Phase_Duration_Months      0.58
# 37  Estimated_Timeline_Months    External_Dependencies_Count      0.55
# 31         Project_Budget_USD  Current_Phase_Duration_Months      0.50
# 15                  Team_Size  Current_Phase_Duration_Months      0.50
# 40  Estimated_Timeline_Months              Schedule_Pressure      0.47
# 63          Stakeholder_Count  Current_Phase_Duration_Months      0.45
# ...

# %%
# Visualize top correlated pairs
top_pairs = corr_pairs[['feature_1','feature_2']].head(15).values.tolist()
for f1, f2 in top_pairs:
    plt.figure(figsize=(6,4))
    sns.scatterplot(data=df, x=f1, y=f2)
    plt.title(f"Scatter: {f1} vs {f2} (corr={corr.loc[f1,f2]:.2f})")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Team_Size', y='Complexity_Score', color='royalblue', s=60)
plt.title('Scatter Plot: Team Size vs Complexity Score', fontsize=14)
plt.xlabel('Team Size')
plt.ylabel('Complexity Score')
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x='Team_Size', y='Complexity_Score', scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
plt.title('Regression Line: Team Size vs Complexity Score', fontsize=14)
plt.xlabel('Team Size')
plt.ylabel('Complexity Score')
plt.show()

# %%
correlation_value = df['Team_Size'].corr(df['Complexity_Score'])
print(f"Pearson correlation between Team_Size and Complexity_Score: {correlation_value:.3f}")
#moderate positive correlation
# Out:
# Pearson correlation between Team_Size and Complexity_Score: 0.467

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Team_Size', y='Stakeholder_Count', color='steelblue', s=60)
plt.title('Team Size vs Stakeholder Count', fontsize=14)
plt.xlabel('Team Size')
plt.ylabel('Stakeholder Count')
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x='Team_Size', y='Stakeholder_Count',
            scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
plt.title('Regression Plot: Team Size vs Stakeholder Count', fontsize=14)
plt.xlabel('Team Size')
plt.ylabel('Stakeholder Count')
plt.show()

# %%
corr_value = df['Team_Size'].corr(df['Stakeholder_Count'])
print(f"Pearson Correlation (Team_Size vs Stakeholder_Count): {corr_value:.3f}")
#strong positive
# Out:
# Pearson Correlation (Team_Size vs Stakeholder_Count): 0.788

# %%
df['Methodology_Used'].value_counts()
df[['Team_Size', 'Methodology_Used']].head()
#check data types
# Out:
#    Team_Size Methodology_Used
# 0         32        Waterfall
# 1          2           Kanban
# 2          2            Agile
# 3         12            Scrum
# 4         24           Hybrid

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Methodology_Used', y='Team_Size', palette='Set2')
plt.title('Team Size by Methodology Used', fontsize=14)
plt.xlabel('Methodology Used')
plt.ylabel('Team Size')
plt.show()
# Out:
# /tmp/ipython-input-1983574791.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Methodology_Used', y='Team_Size', palette='Set2')

# %%
avg_team = df.groupby('Methodology_Used')['Team_Size'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(data=avg_team, x='Methodology_Used', y='Team_Size', palette='viridis')
plt.title('Average Team Size by Methodology Used', fontsize=14)
plt.xlabel('Methodology Used')
plt.ylabel('Average Team Size')
plt.show()
# Out:
# /tmp/ipython-input-806018493.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_team, x='Methodology_Used', y='Team_Size', palette='viridis')

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Methodology_Used', palette='pastel')
plt.title('Count of Projects by Methodology Used', fontsize=14)
plt.xlabel('Methodology Used')
plt.ylabel('Number of Projects')
plt.show()
# Out:
# /tmp/ipython-input-3399140010.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Methodology_Used', palette='pastel')

# %%
#anova test
import scipy.stats as stats

anova_result = stats.f_oneway(
    *[df[df['Methodology_Used'] == m]['Team_Size'] for m in df['Methodology_Used'].unique()]
)
print(f"ANOVA F-statistic: {anova_result.statistic:.3f}")
print(f"p-value: {anova_result.pvalue:.4f}")
#Significant difference: Team size varies by methodology bcs of p-value < 0.05
# Out:
# ANOVA F-statistic: 537.793
# p-value: 0.0000

# %%
df[['Team_Experience_Level', 'Team_Size']].head()
df['Team_Experience_Level'].unique()
# Out:
# array(['Senior', 'Mixed', 'Junior', 'Expert'], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Team_Experience_Level', y='Team_Size', palette='Set2')
plt.title('Team Size by Experience Level', fontsize=14)
plt.xlabel('Team Experience Level')
plt.ylabel('Team Size')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# /tmp/ipython-input-3953058681.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Team_Experience_Level', y='Team_Size', palette='Set2')

# %%
avg_team_size = df.groupby('Team_Experience_Level')['Team_Size'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(data=avg_team_size, x='Team_Experience_Level', y='Team_Size', palette='viridis')
plt.title('Average Team Size by Experience Level', fontsize=14)
plt.xlabel('Team Experience Level')
plt.ylabel('Average Team Size')
plt.show()
# Out:
# /tmp/ipython-input-2424565172.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_team_size, x='Team_Experience_Level', y='Team_Size', palette='viridis')

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Team_Experience_Level', palette='pastel')
plt.title('Count of Projects by Experience Level', fontsize=14)
plt.xlabel('Team Experience Level')
plt.ylabel('Number of Projects')
plt.show()
# Out:
# /tmp/ipython-input-860814397.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Team_Experience_Level', palette='pastel')

# %%
#anova test

anova_result = stats.f_oneway(
    *[df[df['Team_Experience_Level'] == lvl]['Team_Size'] for lvl in df['Team_Experience_Level'].unique()]
)
print(f"ANOVA F-statistic: {anova_result.statistic:.3f}")
print(f"p-value: {anova_result.pvalue:.4f}")

#p value 0.5253 < 0.05 ?
#No significant difference: Team size is similar across experience levels.
# Out:
# ANOVA F-statistic: 0.745
# p-value: 0.5253
# → No significant difference: Team size is similar across experience levels.

# %%
df[['Team_Size', 'Past_Similar_Projects']].head()
df[['Team_Size', 'Past_Similar_Projects']].describe()
# Out:
#        Team_Size  Past_Similar_Projects
# count    4000.00                4000.00
# mean       15.39                   1.97
# std         9.22                   1.75
# min         2.00                   0.00
# 25%         9.00                   1.00
# 50%        13.00                   2.00
# 75%        20.00                   3.00
# max        50.00                  10.00

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Past_Similar_Projects', y='Team_Size', color='royalblue', s=60)
plt.title('Past Similar Projects vs Team Size', fontsize=14)
plt.xlabel('Past Similar Projects')
plt.ylabel('Team Size')
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x='Past_Similar_Projects', y='Team_Size',
            scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
plt.title('Regression Plot: Past Similar Projects vs Team Size', fontsize=14)
plt.xlabel('Past Similar Projects')
plt.ylabel('Team Size')
plt.show()

# %%
corr_value = df['Past_Similar_Projects'].corr(df['Team_Size'])
print(f"Pearson Correlation (Past_Similar_Projects vs Team_Size): {corr_value:.3f}")

#Little to no correlation: Team size and past experience seem independent.
# Out:
# Pearson Correlation (Past_Similar_Projects vs Team_Size): -0.010

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='External_Dependencies_Count', y='Team_Size',
                color='teal', s=60, alpha=0.7)
plt.title('External Dependencies vs Team Size', fontsize=14)
plt.xlabel('External Dependencies Count')
plt.ylabel('Team Size')
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x='External_Dependencies_Count', y='Team_Size',
            scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
plt.title('Regression Plot: External Dependencies vs Team Size', fontsize=14)
plt.xlabel('External Dependencies Count')
plt.ylabel('Team Size')
plt.show()

# %%
corr_value = df['External_Dependencies_Count'].corr(df['Team_Size'])
print(f"Pearson Correlation (External_Dependencies_Count vs Team_Size): {corr_value:.3f}")

if corr_value > 0.7:
    print("→ Strong positive correlation: Larger teams handle more external dependencies.")
elif corr_value > 0.4:
    print("→ Moderate positive correlation: Some link between team size and dependencies.")
elif corr_value > 0.1:
    print("→ Weak positive correlation: Slight link between them.")
else:
    print("→ Little to no correlation: Team size doesn’t depend on dependencies.")
# Out:
# Pearson Correlation (External_Dependencies_Count vs Team_Size): 0.325
# → Weak positive correlation: Slight link between them.

# %%
avg_team = df.groupby('External_Dependencies_Count')['Team_Size'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.lineplot(data=avg_team, x='External_Dependencies_Count', y='Team_Size',
             marker='o', color='darkorange')
plt.title('Average Team Size Vs External Dependencies', fontsize=14)
plt.xlabel('External Dependencies Count')
plt.ylabel('Average Team Size')
plt.grid(True, alpha=0.3)
plt.show()

# %%
df[['Change_Request_Frequency', 'Team_Size']].info()
df[['Change_Request_Frequency', 'Team_Size']].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 2 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Change_Request_Frequency  4000 non-null   float64
#  1   Team_Size                 4000 non-null   int64
# dtypes: float64(1), int64(1)
# memory usage: 62.6 KB
#        Change_Request_Frequency  Team_Size
# count                   4000.00    4000.00
# mean                       1.64      15.39
# std                        1.17       9.22
# min                        0.01       2.00
# 25%                        0.76       9.00
# 50%                        1.37      13.00
# 75%                        2.23      20.00
# max                        8.84      50.00

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data=df, x='Change_Request_Frequency', y='Team_Size',
                color='royalblue', s=60, alpha=0.7)
plt.title('Change Request Frequency vs Team Size', fontsize=14)
plt.xlabel('Change Request Frequency')
plt.ylabel('Team Size')
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.regplot(data=df, x='Change_Request_Frequency', y='Team_Size',
            scatter_kws={'alpha':0.6}, line_kws={'color':'red'})
plt.title('Change Request Frequency vs Team Size', fontsize=14)
plt.xlabel('Change Request Frequency')
plt.ylabel('Team Size')
plt.show()

# %%
corr_value = df['Change_Request_Frequency'].corr(df['Team_Size'])
print(f"Pearson Correlation (Change_Request_Frequency vs Team_Size): {corr_value:.3f}")

if corr_value > 0.7:
    print("→ Strong positive correlation: Larger teams handle more frequent change requests.")
elif corr_value > 0.4:
    print("→ Moderate positive correlation: Some relationship between team size and change frequency.")
elif corr_value > 0.1:
    print("→ Weak positive correlation: Slight relationship.")
else:
    print("→ Little to no correlation: Change requests seem independent of team size.")
# Out:
# Pearson Correlation (Change_Request_Frequency vs Team_Size): 0.012
# → Little to no correlation: Change requests seem independent of team size.

# %%
# Box Plot: Team Size by Project Phase
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Project_Phase', y='Team_Size', palette='Set2')
plt.title('Team Size vs Project Phase', fontsize=14)
plt.xlabel('Project Phase')
plt.ylabel('Team Size')
plt.show()
# Out:
# /tmp/ipython-input-3006744457.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Project_Phase', y='Team_Size', palette='Set2')

# %%
# Bar Plot: Average Team Size by Project Phase
avg_team_phase = df.groupby('Project_Phase')['Team_Size'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(data=avg_team_phase, x='Project_Phase', y='Team_Size', palette='viridis')
plt.title('Average Team Size by Project Phase', fontsize=14)
plt.xlabel('Project Phase')
plt.ylabel('Average Team Size')
plt.show()
# Out:
# /tmp/ipython-input-1234012703.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_team_phase, x='Project_Phase', y='Team_Size', palette='viridis')

# %%
# Count Plot: Number of Projects by Project Phase
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Project_Phase', palette='pastel')
plt.title('Count of Projects by Project Phase', fontsize=14)
plt.xlabel('Project Phase')
plt.ylabel('Number of Projects')
plt.show()
# Out:
# /tmp/ipython-input-1566306571.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Project_Phase', palette='pastel')

# %%
# ANOVA Test
anova_result_phase = stats.f_oneway(
    *[df[df['Project_Phase'] == phase]['Team_Size'] for phase in df['Project_Phase'].unique()]
)
print(f"ANOVA F-statistic: {anova_result_phase.statistic:.3f}")
print(f"p-value: {anova_result_phase.pvalue:.4f}")
# Out:
# ANOVA F-statistic: 0.430
# p-value: 0.7869

# %%
# Interpretation
if anova_result_phase.pvalue < 0.05:
    print("Significant difference: Team size varies across project phases.")
else:
    print("No significant difference: Team size is similar across project phases.")
# Out:
# No significant difference: Team size is similar across project phases.

# %%
# Box Plot: Team Size by Requirement Stability
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='Requirement_Stability', y='Team_Size', palette='Set2')
plt.title('Team Size by Requirement Stability', fontsize=14)
plt.xlabel('Requirement Stability')
plt.ylabel('Team Size')
plt.show()
# Out:
# /tmp/ipython-input-1631131488.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Requirement_Stability', y='Team_Size', palette='Set2')

# %%
# Bar Plot: Average Team Size by Requirement Stability
avg_team_req = df.groupby('Requirement_Stability')['Team_Size'].mean().reset_index()

plt.figure(figsize=(8,6))
sns.barplot(data=avg_team_req, x='Requirement_Stability', y='Team_Size', palette='viridis')
plt.title('Average Team Size Vs Requirement Stability', fontsize=14)
plt.xlabel('Requirement Stability')
plt.ylabel('Average Team Size')
plt.show()
# Out:
# /tmp/ipython-input-420621318.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_team_req, x='Requirement_Stability', y='Team_Size', palette='viridis')

# %%
# Count Plot: Number of Projects by Requirement Stability
plt.figure(figsize=(8,6))
sns.countplot(data=df, x='Requirement_Stability', palette='pastel')
plt.title('Count of Projects by Requirement Stability', fontsize=14)
plt.xlabel('Requirement Stability')
plt.ylabel('Number of Projects')
plt.show()
# Out:
# /tmp/ipython-input-374174842.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Requirement_Stability', palette='pastel')

# %%
# ANOVA Test
anova_result_req = stats.f_oneway(
    *[df[df['Requirement_Stability'] == level]['Team_Size'] for level in df['Requirement_Stability'].unique()]
)
print(f"ANOVA F-statistic: {anova_result_req.statistic:.3f}")
print(f"p-value: {anova_result_req.pvalue:.4f}")
# Out:
# ANOVA F-statistic: 0.762
# p-value: 0.4667

# %%
# Interpretation
if anova_result_req.pvalue < 0.05:
    print("Significant difference: Team size varies across requirement stability levels.")
else:
    print("No significant difference: Team size is similar across requirement stability levels.")
# Out:
# No significant difference: Team size is similar across requirement stability levels.
